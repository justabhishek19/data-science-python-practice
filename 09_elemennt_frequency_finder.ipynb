# %% [markdown]
# # Write a function to find out the occurences of an element in a list

# %%
def frequency_counter(fruits,target):
    count = 0
    for fruit in fruits:
        if fruit == target:
            count += 1
    return count

# %%
items = ['apple','banana','apple','orange','banana','apple']
target = 'apple'
frequency_counter(items,target)
# Out:
# 3
