# %% [markdown]
# # Write a function called count_vowels that takes a string as input and returns the count of vowels (a, e, i, o, u) in the string.

# %%
def count_vowels(string):
    string = string.lower()
    vowels = 'aeiou'

    count = 0
    vowels_count = {}
    for ch in string:
        if ch in vowels:
            count += 1
            vowels_count[ch] = vowels_count.get(ch,0) + 1
    print(f'Total Vowels: {count} ')
    return vowels_count

# %%
text = "Hello, how are you?"
count_vowels(text)
# Out:
# Total Vowels: 7
# {'e': 2, 'o': 3, 'a': 1, 'u': 1}
