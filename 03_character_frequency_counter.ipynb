# %% [markdown]
# # Write a Python function that takes a string as input and counts the frequency of each character in the string. The function should return a dictionary where the keys represent the characters and the values represent their corresponding frequencies.

# %%
def count_character_frequency(string):
    string = string.replace(' ','')
    res = {}
    for char in string:
        if char in res:
            res[char] = res[char]+1
        else:
            res[char] = 1
    return res

# %%
count_character_frequency('Namaste Duniya')
# Out:
# {'N': 1,
#  'a': 3,
#  'm': 1,
#  's': 1,
#  't': 1,
#  'e': 1,
#  'D': 1,
#  'u': 1,
#  'n': 1,
#  'i': 1,
#  'y': 1}

# %% [markdown]
# # ALTERNATIVE

# %%
def count_character_frequency(string):
    string = string.replace(' ','')
    res = {}
    for char in string:
        res[char] = res.get(char,0)+1
    return res

# %%
count_character_frequency('Namaste Duniya')
# Out:
# {'N': 1,
#  'a': 3,
#  'm': 1,
#  's': 1,
#  't': 1,
#  'e': 1,
#  'D': 1,
#  'u': 1,
#  'n': 1,
#  'i': 1,
#  'y': 1}
