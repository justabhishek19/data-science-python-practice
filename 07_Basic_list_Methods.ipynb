# %% [markdown]
# # Creations

# %%
numbers = [10,20,30,40,50]
fruits = ['apple','banana','cherry']
mixed = [7,3.14,'abc',True,None]
type(mixed)
# Out:
# list

# %% [markdown]
# # Access

# %%
numbers[2]
# Out:
# 30

# %%
fruits[0]
# Out:
# 'apple'

# %%
mixed[3]
# Out:
# True

# %% [markdown]
# # Traversal

# %%
for fruit in fruits:
    print(fruit, end=" ")
# Out:
# apple banana cherry

# %%
for x in mixed:
    print(x, end=" ")
# Out:
# 7 3.14 abc True None

# %% [markdown]
# # Insertion

# %%
# append
numbers.append(60)
numbers
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
# insert
numbers.insert(3,35)
numbers
# Out:
# [10, 20, 30, 35, 40, 50, 60]

# %% [markdown]
# # Concatenation

# %%
# extend
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
more_fruits = ['mango','lemon']

fruits.extend(more_fruits)

fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'lemon']

# %%
some_more_fruits = ('kiwi','watermelon')  # This is a tuple and not list,still it works
fruits.extend(some_more_fruits)

fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'lemon', 'kiwi', 'watermelon']

# %%
# concatenation

li1 = [1,2,3]
li2 = [4,5]
li1+li2
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # Deletion

# %%
li = [3,4,6,4,1,6,2]
li.remove(6)

li
# Out:
# [3, 4, 4, 1, 6, 2]

# %%
li.pop(2)  # pop is removing plus returning that removed number
# Out:
# 4

# %%
print(li)
# Out:
# [3, 4, 1, 6, 2]

# %%
# del
del li[2]

# %%
li
# Out:
# [3, 4, 6, 2]

# %%
# clear
li.clear()
li
# Out:
# []

# %% [markdown]
# # Updation

# %%
mixed
# Out:
# [7, 3.14, 'abc', True, None]

# %%
mixed[1] = 6.626
mixed
# Out:
# [7, 6.626, 'abc', True, None]

# %% [markdown]
# # Count

# %%
li = [2,3,4,2,2,5,3]
li
# Out:
# [2, 3, 4, 2, 2, 5, 3]

# %%
li.count(2)
# Out:
# 3

# %%
li.count(3)
# Out:
# 2

# %%
li.count(5)
# Out:
# 1

# %% [markdown]
# # Sort

# %%
li
# Out:
# [2, 3, 4, 2, 2, 5, 3]

# %%
li.sort()  # This is view not copy

# %%
li
# Out:
# [2, 2, 2, 3, 3, 4, 5]

# %%
li1 = [2, 3, 4, 2, 2, 5, 3]    
sorted(li1)                   # This is copy not view
# Out:
# [2, 2, 2, 3, 3, 4, 5]

# %%
li1
# Out:
# [2, 3, 4, 2, 2, 5, 3]

# %% [markdown]
# # Reverse

# %%
li = [3,4,1,2,-5,7,4]
li.reverse()    # It return a view not copy

# %%
li
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %% [markdown]
# # copy

# %%
li = [3,4,1,2,-5,7,4]

# %%
li_copy = li.copy()

# %%
li_copy
# Out:
# [3, 4, 1, 2, -5, 7, 4]

# %%
li_copy[0] = 9999
li_copy
# Out:
# [9999, 4, 1, 2, -5, 7, 4]

# %%
li
# Out:
# [3, 4, 1, 2, -5, 7, 4]

# %% [markdown]
# # split

# %%
numbers
# Out:
# [10, 20, 30, 35, 40, 50, 60]

# %%
numbers[3:]
# Out:
# [35, 40, 50, 60]

# %%
numbers[0:3]
# Out:
# [10, 20, 30]
