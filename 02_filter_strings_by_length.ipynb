# %% [markdown]
# ## Write a Python function that takes a list of strings as input and returns a new list containing only the strings that have a length greater than a given value.

# %%
def filter_strings_by_length(strings,length):
    res = []
    for string in strings:
        if len(string)>length:
            res.append(string)
    return res

# %%
fruits = ['apple','banana','watermelon','kiwi','pineapple','orange','mango','strawberry']
length = 6
filtered_fruits = filter_strings_by_length(fruits,length)
print(filtered_fruits)
# Out:
# ['watermelon', 'pineapple', 'strawberry']
